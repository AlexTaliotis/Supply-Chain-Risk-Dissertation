# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Toyota

# %%
file_path = '/content/drive/My Drive/DISS DATA/BoL_Toyota.xlsx'
df = pd.read_excel(file_path)
print(df.head())
# Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])
# ========== 2. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

print(group_total.head(500000))
# Out:
#   Arrival Date                         Company Name  \
# 0   2024-09-29               Toyota Motor Sales Usa
# 1   2024-09-29               Toyota Motor Sales Usa
# 2   2024-09-29  Bastian Solutions Llc I A Toyota Ad
# 3   2024-09-29      Toyota Tsusho Nexty Electronics
# 4   2024-09-28          Southern States Toyota Lift
#
#                      Supplier Name  \
# 0                Toyota Motor Corp
# 1                Toyota Motor Corp
# 2                Autostore Sp Zo O
# 3  Toyota Tsusho Nexty Electronics
# 4                    Combilift Ulc
#
#                           Product Description  \
# 0  Toyota Passenger Vehicle Emergency Contact
# 1    Lexus Passenger Vehicle Emergencycontact
# 2                                       Piece
# 3      Unpopulated Bare Printed Circuit Board
# 4                                   Forklifts
#
#                    Destination Port Departure Port Supplier Country  TEU  \
# 0                  Jacksonville, Fl       Gamagori            Japan  0.0
# 1                  Jacksonville, Fl       Gamagori            Japan  0.0
# 2  New York/Newark Area, Newark, Nj    Bremerhaven          Germany  1.5
# 3                    Long Beach, Ca      Hong Kong        Hong Kong  1.0
# 4               Port Everglades, Fl      Rotterdam      Netherlands  1.5
#
#     Weight  Containers Count  ... Supplier Total Shipments Container Size  \
# 0  2069555                 1  ...                    30233            NaN
# 1  1369205                 1  ...                    30233            NaN
# 2      796                 1  ...                        5            NaN
# 3      642                 1  ...                      606            NaN
# 4    13200                 1  ...                     7435            NaN
#
#                Marks & Numbers  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3  Toyota Tsusho Mcallen China
# 4                          NaN
#
#                              Product Description Raw Quantity Unit  Voyage  \
# 0  Ex-J1339 Toyota Passenger Vehicle(S) Emergency...           UNT     146
# 1  Ex-T1336 Lexus Passenger Vehicle(S) Emergencyc...           UNT     146
# 2                                         1 Piece(S)           PCS    437w
# 3             Unpopulated Bare Printed Circuit Board           CTN    065e
# 4                                          Forklifts           PCS    092w
#
#    Company Total Shipments                           HS Code Full Description  \
# 0                    30779  Optical, photographic, cinematographic, measur...
# 1                    30779  Nuclear reactors, boilers, machinery and mecha...
# 2                        1  Miscellaneous edible preparations ; Ice cream ...
# 3                     9285  Electrical machinery and equipment and parts t...
# 4                      127                                                NaN
#
#     HS Code                                HS Code Description
# 0  900130.0                                     Contact lenses
# 1  841830.0  Freezers of the chest type, not exceeding 800 ...
# 2  210500.0  Ice cream and other edible ice, whether or not...
# 3  853890.0                                              Other
# 4       0.0                                                NaN
#
# [5 rows x 25 columns]
#      Quarter   HS Code  TotalVolume  \
# 0     2015Q1   10290.0          151
# 1     2015Q1   13000.0           31
# 2     2015Q1   30613.0           46
# 3     2015Q1   30749.0         1200
# 4     2015Q1   30760.0            8
# ...      ...       ...          ...
# 7852  2024Q3  911290.0           91
# 7853  2024Q3  950629.0           78
# 7854  2024Q3  961800.0          119
# 7855  2024Q3  970600.0          217
# 7856  2024Q3  981800.0        33634
#
#                                         FullDescription
# 0            Live animals ; Live bovine animals ; Other
# 1                                          Live animals
# 2     Fish and crustaceans, molluscs and other aquat...
# 3     Fish and crustaceans, molluscs and other aquat...
# 4     Fish and crustaceans, molluscs and other aquat...
# ...                                                 ...
# 7852  Clocks and watches and parts thereof ; Clock c...
# 7853  Toys, games and sports requisites; parts and a...
# 7854  Miscellaneous manufactured articles ; Tailors'...
# 7855  Works of art, collectors' pieces and antiques ...
# 7856                  Special classification provisions
#
# [7857 rows x 4 columns]

# %% [markdown]
# Ford Motor Company

# %%
file_path = '/content/drive/My Drive/DISS DATA/Ford Motor Company-10-19-2024.xlsx'
df1 = pd.read_excel(file_path)
file_path = '/content/drive/My Drive/DISS DATA/Ford Motor Company-10-19-2024 (1).xlsx'
df2 = pd.read_excel(file_path)
# Concatenate both datasets
df = pd.concat([df1, df2], ignore_index=True)
# Step 2: Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])

print(df['Arrival Date'].dtypes)
# ========== 3. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')
# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)
print(group_total.head(500000))
# Out:
# datetime64[ns]
#      Quarter   HS Code  TotalVolume  \
# 0     2015Q1   30613.0         26.0
# 1     2015Q1   40390.0        222.0
# 2     2015Q1   40510.0         30.0
# 3     2015Q1   40590.0         56.0
# 4     2015Q1   91091.0         20.0
# ...      ...       ...          ...
# 4732  2024Q3  930610.0        762.0
# 4733  2024Q3  940190.0         19.0
# 4734  2024Q3  940350.0         54.0
# 4735  2024Q3  960321.0          3.0
# 4736  2024Q3  981800.0        400.0
#
#                                         FullDescription
# 0     Fish and crustaceans, molluscs and other aquat...
# 1     Dairy produce; birds eggs; natural honey; edib...
# 2     Dairy produce; birds eggs; natural honey; edib...
# 3     Dairy produce; birds eggs; natural honey; edib...
# 4     Coffee, tea, maté and spices ; Ginger, saffron...
# ...                                                 ...
# 4732  Arms and ammunition; parts and accessories the...
# 4733  Furniture; bedding, mattresses, mattress suppo...
# 4734  Furniture; bedding, mattresses, mattress suppo...
# 4735  Miscellaneous manufactured articles ; Brooms, ...
# 4736                  Special classification provisions
#
# [4737 rows x 4 columns]

# %% [markdown]
# Tesla

# %%
file_path = '/content/drive/My Drive/DISS DATA/Tesla_BoL_Dataset.xlsx'
df = pd.read_excel(file_path)
print(df.head())
# Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])
# ========== 2. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

print(group_total.head(500000))
# Out:
#   Arrival Date Company Name                            Supplier Name  \
# 0   2024/09/28    Tesla Inc  Panasonic Operational Excellence Co Ltd
# 1   2024/09/28    Tesla Inc                        Daehyun St Co Ltd
# 2   2024/09/28    Tesla Inc  Panasonic Operational Excellence Co Ltd
# 3   2024/09/28    Tesla Inc  Panasonic Operational Excellence Co Ltd
# 4   2024/09/28    Tesla Inc                    Posco Future M Co Ltd
#
#           Product Description Destination Port Departure Port  \
# 0       Separator Film Pervio  Los Angeles, Ca          Pusan
# 1  Single Sided Adhesive Tape  Los Angeles, Ca          Pusan
# 2       Separator Film Pervio  Los Angeles, Ca          Pusan
# 3                         NaN  Los Angeles, Ca          Pusan
# 4                Anode Active  Los Angeles, Ca          Pusan
#
#     Supplier Country  TEU  Weight  Containers Count  ...  \
# 0  Republic Of Korea  3.0   15123                 2  ...
# 1  Republic Of Korea  1.5    5565                 1  ...
# 2  Republic Of Korea  3.0   14803                 2  ...
# 3  Republic Of Korea  4.5   23993                 3  ...
# 4  Republic Of Korea  2.0   18648                 1  ...
#
#   Supplier Total Shipments Container Size  Marks & Numbers  \
# 0                    22072            NaN              NaN
# 1                      316            NaN  Tesla Dia Korea
# 2                    22072            NaN              NaN
# 3                    22072            NaN              NaN
# 4                      428            NaN     Pallet Korea
#
#                          Product Description Raw Quantity Unit  Voyage  \
# 0  40 Packages Of Separator Film Pervio Sf5048 I           PKG    003e
# 1   8 Packages Of Single Sided Adhesive Tape Inv           PKG    003e
# 2  40 Packages Of Separator Film Pervio Sf5048 I           PKG    003e
# 3                                 60 Packages Of           PKG    003e
# 4    56 Package Of Anode Active Material Invoice           PKG    003e
#
#    Company Total Shipments                           HS Code Full Description  \
# 0                    23244  Photographic or cinematographic goods ; Photog...
# 1                    23244  Impregnated, coated, covered or laminated text...
# 2                    23244  Photographic or cinematographic goods ; Photog...
# 3                    23244  Electrical machinery and equipment and parts t...
# 4                    23244  Miscellaneous edible preparations ; Yeasts (ac...
#
#     HS Code                                HS Code Description
# 0  370220.0  Photographic film in rolls, sensitized, unexpo...
# 1  590610.0       Adhesive tape of a width not exceeding 20 cm
# 2  370220.0  Photographic film in rolls, sensitized, unexpo...
# 3  853649.0                                              Other
# 4  210210.0                                      Active yeasts
#
# [5 rows x 25 columns]
#      Quarter   HS Code  TotalVolume  \
# 0     2015Q1  731010.0          4.0
# 1     2015Q1  740710.0          3.0
# 2     2015Q1  850300.0         14.0
# 3     2015Q2  740710.0         24.0
# 4     2015Q2  850300.0          8.0
# ...      ...       ...          ...
# 2172  2024Q3  841581.0          8.0
# 2173  2024Q3  850650.0         60.0
# 2174  2024Q3  851030.0         13.0
# 2175  2024Q3  853649.0         60.0
# 2176  2024Q3  854311.0      55404.0
#
#                                         FullDescription
# 0     Articles of iron or steel ; Tanks, casks, drum...
# 1     Copper and articles thereof ; Copper bars, rod...
# 2     Electrical machinery and equipment and parts t...
# 3     Copper and articles thereof ; Copper bars, rod...
# 4     Electrical machinery and equipment and parts t...
# ...                                                 ...
# 2172  Nuclear reactors, boilers, machinery and mecha...
# 2173  Electrical machinery and equipment and parts t...
# 2174  Electrical machinery and equipment and parts t...
# 2175  Electrical machinery and equipment and parts t...
# 2176  Electrical machinery and equipment and parts t...
#
# [2177 rows x 4 columns]

# %% [markdown]
# Nissan

# %%
file_path = '/content/drive/My Drive/DISS DATA/BoL_Nissan.xlsx'
df = pd.read_excel(file_path)
print(df.head())
# Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])
# ========== 2. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

print(group_total.head(500000))
# Out:
#           Arrival Date               Company Name         Supplier Name  \
# 0           11/13/2024  Nissan North America Inc   Nissan Motor Co Ltd
# 1           11/13/2024  Nissan North America Inc   Nissan Motor Co Ltd
# 2           11/13/2024  Nissan North America Inc   Nissan Motor Co Ltd
# 3  2024-04-11 00:00:00  Nissan North America Inc   Nissan Motor Co Ltd
# 4  2024-04-11 00:00:00  Nissan North America Inc   Nissan Motor Co Ltd
#
#                                  Product Description Destination Port  \
# 0  Nissan Motor Vehicles Emerge Ncy Contact Chemt...   Long Beach, Ca
# 1  Nissan Motor Vehicles Emerge Ncy Contact Chemt...   Long Beach, Ca
# 2  Nissan Motor Vehicles Emerge Ncy Contact Chemt...   Long Beach, Ca
# 3  Nissan Motor Vehicles Emerge Ncy Contact Chemt...  Los Angeles, Ca
# 4  Nissan Motor Vehicles Emerge Ncy Contact Chemt...  Los Angeles, Ca
#
#   Departure Port Supplier Country  HS Code  \
# 0       YANGSHAN            Japan  8703.24
# 1       YANGSHAN            Japan  8703.24
# 2       YANGSHAN            Japan  8703.24
# 3       YANGSHAN            Japan  8703.24
# 4       YANGSHAN            Japan  8703.24
#
#                                  HS Code Description  \
# 0  Motor cars and other motor vehicles principall...
# 1  Motor cars and other motor vehicles principall...
# 2  Motor cars and other motor vehicles principall...
# 3  Motor cars and other motor vehicles principall...
# 4  Motor cars and other motor vehicles principall...
#
#                             HS Code Full Description  Company Total Shipments  \
# 0  Vehicles other than railway or tramway rolling...                    50361
# 1  Vehicles other than railway or tramway rolling...                    50361
# 2  Vehicles other than railway or tramway rolling...                    50361
# 3  Vehicles other than railway or tramway rolling...                    50361
# 4  Vehicles other than railway or tramway rolling...                    50361
#
#   Estimated Arrival Date                            RAW Product Description  \
# 0    2024-11-11 00:00:00  Nissan Motor Vehicles Emerge Ncy Contact:Chemt...
# 1    2024-11-11 00:00:00  Nissan Motor Vehicles Emerge Ncy Contact:Chemt...
# 2    2024-11-11 00:00:00  Nissan Motor Vehicles Emerge Ncy Contact:Chemt...
# 3    2024-03-11 00:00:00  Nissan Motor Vehicles Emerge Ncy Contact:Chemt...
# 4    2024-03-11 00:00:00  Nissan Motor Vehicles Emerge Ncy Contact:Chemt...
#
#   Shipping Route  Quantity
# 0   Asia,Pacific         2
# 1   Asia,Pacific         2
# 2   Asia,Pacific         2
# 3   Asia,Pacific         2
# 4   Asia,Pacific         2
#      Quarter  HS Code  TotalVolume  \
# 0     2015Q1   401.30           73
# 1     2015Q1   402.21        21832
# 2     2015Q1   402.91          276
# 3     2015Q1   403.90          284
# 4     2015Q1  1118.00          156
# ...      ...      ...          ...
# 2364  2024Q3  8703.23            6
# 2365  2024Q3  8703.24            4
# 2366  2024Q3  8703.80            5
# 2367  2024Q4  8483.90           95
# 2368  2024Q4  8703.24           25
#
#                                         FullDescription
# 0     Dairy produce; birds eggs; natural honey; edib...
# 1     Dairy produce; birds eggs; natural honey; edib...
# 2     Dairy produce; birds eggs; natural honey; edib...
# 3     Dairy produce; birds eggs; natural honey; edib...
# 4     Products of the milling industry; malt; starch...
# ...                                                 ...
# 2364  Vehicles other than railway or tramway rolling...
# 2365  Vehicles other than railway or tramway rolling...
# 2366  Vehicles other than railway or tramway rolling...
# 2367  Nuclear reactors, boilers, machinery and mecha...
# 2368  Vehicles other than railway or tramway rolling...
#
# [2369 rows x 4 columns]

# %% [markdown]
# Mazda

# %%
file_path = '/content/drive/My Drive/DISS DATA/BoL_Mazda.xlsx'
df = pd.read_excel(file_path)
print(df.head())
# Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])
# ========== 2. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

print(group_total.head(500000))
# Out:
#           Arrival Date                 Company Name      Supplier Name  \
# 0  2024-12-12 00:00:00  Mazda Motor Of America Inc   Mazda Motor Corp
# 1  2024-12-12 00:00:00  Mazda Motor Of America Inc   Mazda Motor Corp
# 2  2024-12-12 00:00:00  Mazda Motor Of America Inc   Mazda Motor Corp
# 3  2024-12-12 00:00:00  Mazda Motor Of America Inc   Mazda Motor Corp
# 4  2024-12-12 00:00:00  Mazda Motor Of America Inc   Mazda Motor Corp
#
#              Product Description Destination Port Departure Port  \
# 0                     Automotive   Charleston, Sc          Pusan
# 1            Gear Motor Vehicles   Charleston, Sc          Pusan
# 2             Automotive Vehicle   Charleston, Sc          Pusan
# 3                           Gear   Charleston, Sc          Pusan
# 4  Automotive Vehicle Production   Charleston, Sc          Pusan
#
#   Supplier Country  HS Code  \
# 0            Japan   8415.9
# 1            Japan   8708.4
# 2            Japan   8415.9
# 3            Japan   8805.1
# 4            Japan   8415.9
#
#                                  HS Code Description  \
# 0                                              Parts
# 1                       Gear boxes and parts thereof
# 2                                              Parts
# 3  Aircraft launching gear and parts thereof; dec...
# 4                                              Parts
#
#                             HS Code Full Description  Company Total Shipments  \
# 0  Nuclear reactors, boilers, machinery and mecha...                    14240
# 1  Vehicles other than railway or tramway rolling...                    14240
# 2  Nuclear reactors, boilers, machinery and mecha...                    14240
# 3  Aircraft, spacecraft, and parts thereof ; Airc...                    14240
# 4  Nuclear reactors, boilers, machinery and mecha...                    14240
#
#   Estimated Arrival Date                  RAW Product Description  \
# 0             12/13/2024                         Automotive Parts
# 1             12/13/2024            Gear Boxes For Motor Vehicles
# 2             12/13/2024             Automotive Parts For Vehicle
# 3             12/13/2024                               Gear Boxes
# 4             12/13/2024  Automotive Parts For Vehicle Production
#
#        Shipping Route  Quantity
# 0  Asia,Transatlantic        40
# 1  Asia,Transatlantic        46
# 2  Asia,Transatlantic       368
# 3  Asia,Transatlantic        69
# 4  Asia,Transatlantic        80
#     Quarter  HS Code  TotalVolume  \
# 0    2015Q1  2710.19           30
# 1    2015Q1  8201.40           72
# 2    2015Q1  8409.91         2070
# 3    2015Q1  8483.90         6402
# 4    2015Q1  8512.40           70
# ..      ...      ...          ...
# 690  2024Q4  8708.50         2830
# 691  2024Q4  8708.91           89
# 692  2024Q4  8708.99         8697
# 693  2024Q4  8805.10           69
# 694  2024Q4  9818.00          346
#
#                                        FullDescription
# 0    Mineral fuels, mineral oils and products of th...
# 1    Tools, implements, cutlery, spoons and forks, ...
# 2    Nuclear reactors, boilers, machinery and mecha...
# 3    Nuclear reactors, boilers, machinery and mecha...
# 4    Electrical machinery and equipment and parts t...
# ..                                                 ...
# 690  Vehicles other than railway or tramway rolling...
# 691  Vehicles other than railway or tramway rolling...
# 692  Vehicles other than railway or tramway rolling...
# 693  Aircraft, spacecraft, and parts thereof ; Airc...
# 694                  Special classification provisions
#
# [695 rows x 4 columns]

# %% [markdown]
# Mercedes Benz

# %%
file_path = '/content/drive/My Drive/DISS DATA/BoL_Mercedes_Benz.xlsx'
df = pd.read_excel(file_path)
print(df.head())
# Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])
# ========== 2. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

print(group_total.head(500000))
# Out:
#           Arrival Date            Company Name        Supplier Name  \
# 0  2024-12-12 00:00:00  Mercedes Benz Usa Llc     Mercedes Benz Ag
# 1  2024-12-12 00:00:00  Mercedes Benz Usa Llc      Daimler Ag Werk
# 2  2024-12-12 00:00:00  Mercedes Benz Usa Llc   Daimler Ag Werk011
# 3  2024-11-12 00:00:00  Mercedes Benz Usa Llc     Mercedes Benz Ag
# 4  2024-11-12 00:00:00  Mercedes Benz Usa Llc     Mercedes Benz Ag
#
#                                  Product Description Destination Port  \
# 0  Sprinter Sprinter Sprinter Sprinter Sprinter S...   Charleston, Sc
# 1  Mercedes Benz Passenger Cars Mercedes Benz Pas...   Long Beach, Ca
# 2  Mercedes Benz Passenger Cars Mercedes Benz Pas...   Long Beach, Ca
# 3  Technology Technology Technology Technology Te...    Baltimore, Md
# 4                                          Cle Matic    Baltimore, Md
#
#   Departure Port Supplier Country  HS Code  \
# 0    Bremerhaven          Germany      NaN
# 1    Bremerhaven          Germany  4012.11
# 2    Bremerhaven          Germany  4012.11
# 3    Bremerhaven          Germany  5112.19
# 4    Bremerhaven          Germany  2936.27
#
#                                  HS Code Description  \
# 0                                                NaN
# 1  Of a kind used on motor cars (including statio...
# 2  Of a kind used on motor cars (including statio...
# 3                                              Other
# 4      Vitamin C (Ascorbic acid) and its derivatives
#
#                             HS Code Full Description  Company Total Shipments  \
# 0                                                NaN                    33321
# 1  Rubber and articles thereof ; Retreaded or use...                    33321
# 2  Rubber and articles thereof ; Retreaded or use...                    33321
# 3  Wool, fine or coarse animal hair; horsehair ya...                    33321
# 4  Organic chemicals ; Provitamins and vitamins, ...                    33321
#
#   Estimated Arrival Date                            RAW Product Description  \
# 0    2024-07-12 00:00:00  Sprinter Sprinter Sprinter Sprinter Sprinter S...
# 1    2024-11-12 00:00:00  Mercedes-Benz Passenger Cars Mercedes-Benz Pas...
# 2    2024-11-12 00:00:00  Mercedes-Benz Passenger Cars Mercedes-Benz Pas...
# 3    2024-10-12 00:00:00  G 580 With Eq Technology G 580 With Eq Technol...
# 4    2024-10-12 00:00:00                                    Cle 30 4Matic C
#
#      Shipping Route  Quantity
# 0  Eu,Transatlantic        42
# 1        Eu,Pacific        56
# 2        Eu,Pacific       844
# 3  Eu,Transatlantic       100
# 4  Eu,Transatlantic       800
#      Quarter  HS Code  TotalVolume  \
# 0     2015Q1  1209.24         2114
# 1     2015Q1  1702.90           43
# 2     2015Q1  2106.90          700
# 3     2015Q1  2475.00            1
# 4     2015Q1  2707.50          401
# ...      ...      ...          ...
# 1493  2024Q4  8609.00            1
# 1494  2024Q4  8703.10         9346
# 1495  2024Q4  8703.23            2
# 1496  2024Q4  8705.30         8027
# 1497  2024Q4  9506.31          479
#
#                                         FullDescription
# 0     Oil seeds and oleaginous fruits; miscellaneous...
# 1     Sugars and sugar confectionery ; Other sugars,...
# 2     Miscellaneous edible preparations ; Food prepa...
# 3          Tobacco and manufactured tobacco substitutes
# 4     Mineral fuels, mineral oils and products of th...
# ...                                                 ...
# 1493  Railway or tramway locomotives, rolling-stock ...
# 1494  Vehicles other than railway or tramway rolling...
# 1495  Vehicles other than railway or tramway rolling...
# 1496  Vehicles other than railway or tramway rolling...
# 1497  Toys, games and sports requisites; parts and a...
#
# [1498 rows x 4 columns]

# %% [markdown]
# Honda

# %%
file_path = '/content/drive/My Drive/DISS DATA/BoL_Honda_data.xlsx'
df = pd.read_excel(file_path)
print(df.head())
# Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])
# ========== 2. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

print(group_total.head(500000))
# Out:
#           Arrival Date                  Company Name  \
# 0           11/30/2024      American Honda Motor Co
# 1           10/24/2024  American Honda Motor Co Inc
# 2           10/20/2024  American Honda Motor Co Inc
# 3  2024-05-10 00:00:00  American Honda Motor Co Inc
# 4           09/25/2024  American Honda Motor Co Inc
#
#                   Supplier Name     Product Description Destination Port  \
# 0                   Brembo N V               Spring Kit     New York, Ny
# 1  Moto Honda Da Amazonia Ltda              Motorcycles   Charleston, Sc
# 2  Moto Honda Da Amazonia Ltda              Motorcycles   Charleston, Sc
# 3  Moto Honda Da Amazonia Ltda              Motorcycles      Seattle, Wa
# 4  Moto Honda Da Amazonia Ltda   Motocycles Motorcycles  Los Angeles, Ca
#
#   Departure Port Supplier Country  HS Code  \
# 0          Genoa            Italy  8708.30
# 1         Manaus           Brazil  8714.11
# 2         Manaus           Brazil  8714.11
# 3         Manaus           Brazil  8714.11
# 4         Manaus           Brazil  8711.90
#
#                                  HS Code Description  \
# 0             Brakes and servo-brakes; parts thereof
# 1  Parts and accessories of vehicles of headings ...
# 2  Parts and accessories of vehicles of headings ...
# 3  Parts and accessories of vehicles of headings ...
# 4  Motorcycles (including mopeds) and cycles fitt...
#
#                             HS Code Full Description  Company Total Shipments  \
# 0  Vehicles other than railway or tramway rolling...                    25862
# 1  Vehicles other than railway or tramway rolling...                    25862
# 2  Vehicles other than railway or tramway rolling...                    25862
# 3  Vehicles other than railway or tramway rolling...                    25862
# 4  Vehicles other than railway or tramway rolling...                    25862
#
#   Estimated Arrival Date    RAW Product Description    Shipping Route  \
# 0             11/30/2024  Spring Kit Hs Code 870830  Eu,Transatlantic
# 1    2024-09-10 00:00:00                Motorcycles  Sa,Transatlantic
# 2             09/20/2024                Motorcycles  Sa,Transatlantic
# 3             09/20/2024                Motorcycles        Sa,Pacific
# 4    2024-10-09 00:00:00    Motocycles. Motorcycles        Sa,Pacific
#
#    Quantity
# 0         1
# 1        52
# 2        26
# 3        26
# 4        52
#      Quarter  HS Code  TotalVolume  \
# 0     2015Q1   403.90          596
# 1     2015Q1   713.33           62
# 2     2015Q1   910.91          162
# 3     2015Q1  1702.40          154
# 4     2015Q1  1704.90           89
# ...      ...      ...          ...
# 2441  2024Q4  8708.30            1
# 2442  2024Q4  8711.10            2
# 2443  2024Q4  8711.20          238
# 2444  2024Q4  8714.11          246
# 2445  2024Q4  9503.20          344
#
#                                         FullDescription
# 0     Dairy produce; birds eggs; natural honey; edib...
# 1     Edible vegetables and certain roots and tubers...
# 2     Coffee, tea, maté and spices ; Ginger, saffron...
# 3     Sugars and sugar confectionery ; Other sugars,...
# 4     Sugars and sugar confectionery ; Sugar confect...
# ...                                                 ...
# 2441  Vehicles other than railway or tramway rolling...
# 2442  Vehicles other than railway or tramway rolling...
# 2443  Vehicles other than railway or tramway rolling...
# 2444  Vehicles other than railway or tramway rolling...
# 2445  Toys, games and sports requisites; parts and a...
#
# [2446 rows x 4 columns]

# %% [markdown]
# BMW

# %%
file_path = '/content/drive/My Drive/DISS DATA/BMW_BoL_data.xlsx'
df = pd.read_excel(file_path)
print(df.head())
# Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])
# ========== 2. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

print(group_total.head(500000))
# Out:
#   Arrival Date               Company Name                    Supplier Name  \
# 0   12/29/2024  Bmw Of North America Llc   Bayerische Motoren Werke Ag Vt
# 1   12/29/2024  Bmw Of North America Llc               Bmw Slp S A De C V
# 2   12/29/2024    Bmw Manufacturing Corp                  Ebz Systec Gmbh
# 3   12/29/2024  Bmw Of North America Llc   Bayerische Motoren Werke Ag Vt
# 4   12/27/2024    Bmw Manufacturing Corp            Zf Friedrichshafen Ag
#
#                                  Product Description  \
# 0  Bmw Service Bmw Service Bmw Service Bmw Servic...
# 1                                       Bmw Vehicles
# 2  Other Machines Existing Linefor Residential We...
# 3  Bmw Service Bmw Service Bmw Service Bmw Servic...
# 4                                     Bmw Automotive
#
#                    Destination Port Departure Port Supplier Country  HS Code  \
# 0                       Houston, Tx  Wilhelmshaven          Germany  8431.39
# 1  New York/Newark Area, Newark, Nj       Veracruz           Mexico  8705.30
# 2                    Charleston, Sc    Bremerhaven          Germany  8515.90
# 3                       Houston, Tx  Wilhelmshaven          Germany  8431.39
# 4                    Charleston, Sc     Stadersand          Germany  8415.90
#
#       HS Code Description                           HS Code Full Description  \
# 0                   Other  Nuclear reactors, boilers, machinery and mecha...
# 1  Fire fighting vehicles  Vehicles other than railway or tramway rolling...
# 2                   Parts  Electrical machinery and equipment and parts t...
# 3                   Other  Nuclear reactors, boilers, machinery and mecha...
# 4                   Parts  Nuclear reactors, boilers, machinery and mecha...
#
#    Company Total Shipments Estimated Arrival Date  \
# 0                    16185             12/24/2024
# 1                    16185             12/29/2024
# 2                    19132             12/28/2024
# 3                    16185             12/24/2024
# 4                    19132             12/24/2024
#
#                              RAW Product Description    Shipping Route  \
# 0  Bmw Service Parts Invoice-Number 8721139130 Bm...  Eu,Transatlantic
# 1                                       Bmw Vehicles  Sa,Transatlantic
# 2  S.T.C.Other Parts And Machines For An Existing...  Eu,Transatlantic
# 3  Bmw Service Parts Invoice-Number 8721110340 Bm...  Eu,Transatlantic
# 4                               Bmw Automotive Parts  Eu,Transatlantic
#
#    Quantity
# 0       435
# 1       250
# 2         2
# 3       589
# 4       158
#      Quarter  HS Code  TotalVolume  \
# 0     2015Q1   306.13          264
# 1     2015Q1   602.90            5
# 2     2015Q1   808.10           22
# 3     2015Q1  1604.14          892
# 4     2015Q1  1901.20            1
# ...      ...      ...          ...
# 1397  2024Q4  8705.30         3373
# 1398  2024Q4  8807.30          147
# 1399  2024Q4  9112.90           91
# 1400  2024Q4  9405.30          140
# 1401  2024Q4  9818.00          320
#
#                                         FullDescription
# 0     Fish and crustaceans, molluscs and other aquat...
# 1     Live trees and other plants; bulbs, roots and ...
# 2     Edible fruit and nuts; peel of citrus fruit or...
# 3     Preparations of meat, of fish or of crustacean...
# 4     Preparations of cereals, flour, starch or milk...
# ...                                                 ...
# 1397  Vehicles other than railway or tramway rolling...
# 1398  Aircraft, spacecraft, and parts thereof ; Part...
# 1399  Clocks and watches and parts thereof ; Clock c...
# 1400  Furniture; bedding, mattresses, mattress suppo...
# 1401                  Special classification provisions
#
# [1402 rows x 4 columns]

# %% [markdown]
# General Motors

# %%
file_path = '/content/drive/My Drive/DISS DATA/GM_full_data.xlsx'
df = pd.read_excel(file_path)
print(df.head())
# Convert "Arrival Date" to a proper datetime
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# Drop any rows without a valid date
df = df.dropna(subset=['Arrival Date'])
# ========== 2. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

print(group_total.head(500000))
# Out:
#           Arrival Date         Company Name              Supplier Name  \
# 0  2024-04-12 00:00:00  General Motors Llc   Dong Il Aluminium Co Ltd
# 1  2024-04-12 00:00:00  General Motors Llc   Ceva Logistics Korea Inc
# 2  2024-04-12 00:00:00  General Motors Llc     Sam A Aluminium Co Ltd
# 3  2024-04-12 00:00:00  General Motors Llc      Posco Future M Co Ltd
# 4  2024-04-12 00:00:00  General Motors Llc      Posco Future M Co Ltd
#
#                                  Product Description Destination Port  \
# 0                   Aluminium Foil Dia Dia Lane Krus       Tacoma, Wa
# 1  Automotive Bolts Actual Shpr Iljin Global Hani...   Long Beach, Ca
# 2                           Aluminium Foil Lane Krus       Tacoma, Wa
# 3  Natural Graphite Anode Active Ciplinvula Lane ...       Tacoma, Wa
# 4  Natural Graphite Anode Active Ciplinvula Lane ...       Tacoma, Wa
#
#   Departure Port   Supplier Country  HS Code HS Code Description  \
# 0          Pusan  Republic Of Korea  7410.22    Of copper alloys
# 1          Pusan  Republic Of Korea  8301.60               Parts
# 2          Pusan  Republic Of Korea  7410.22    Of copper alloys
# 3          Pusan  Republic Of Korea  2504.90               Other
# 4          Pusan  Republic Of Korea  2504.90               Other
#
#                             HS Code Full Description  Company Total Shipments  \
# 0  Copper and articles thereof ; Copper foil (whe...                   122588
# 1  Miscellaneous articles of base metal ; Padlock...                   122588
# 2  Copper and articles thereof ; Copper foil (whe...                   122588
# 3  Salt; sulfur; earths and stone; plastering mat...                   122588
# 4  Salt; sulfur; earths and stone; plastering mat...                   122588
#
#   Estimated Arrival Date                            RAW Product Description  \
# 0             11/19/2024  Aluminium Foil Inv Dia24U102501 Dia24U102502 L...
# 1    2024-03-12 00:00:00  New Automotive Parts Bolts Actual Shpr Iljin G...
# 2             11/19/2024  Aluminium Foil Inv No.241025Uc1 So No.10301277...
# 3             11/19/2024  Natural Graphite (Anode Active Material) Cipli...
# 4             11/19/2024  Natural Graphite (Anode Active Material) Cipli...
#
#   Shipping Route  Quantity
# 0   Asia,Pacific        43
# 1   Asia,Pacific       217
# 2   Asia,Pacific        92
# 3   Asia,Pacific        40
# 4   Asia,Pacific        40
#      Quarter  HS Code  TotalVolume  \
# 0     2015Q1  2620.60            6
# 1     2015Q1  2932.12            3
# 2     2015Q1  3105.10          107
# 3     2015Q1  4007.00           20
# 4     2015Q1  4011.40           31
# ...      ...      ...          ...
# 3971  2024Q4  9603.10         1248
# 3972  2024Q4  9603.21            1
# 3973  2024Q4  9606.10            1
# 3974  2024Q4  9706.00          562
# 3975  2024Q4  9810.00          161
#
#                                         FullDescription
# 0     Ores, slag and ash ; Slag, ash and residues (o...
# 1     Organic chemicals ; Heterocyclic compounds wit...
# 2     Fertilizers ; Mineral or chemical fertilizers ...
# 3     Rubber and articles thereof ; Vulcanized rubbe...
# 4     Rubber and articles thereof ; New pneumatic ti...
# ...                                                 ...
# 3971  Miscellaneous manufactured articles ; Brooms, ...
# 3972  Miscellaneous manufactured articles ; Brooms, ...
# 3973  Miscellaneous manufactured articles ; Buttons,...
# 3974  Works of art, collectors' pieces and antiques ...
# 3975                  Special classification provisions
#
# [3976 rows x 4 columns]

# %% [markdown]
# # **Data loading ends here**

# %%
# ========== 3. DEFINE QUARTER COLUMN ==========
df['Quarter'] = df['Arrival Date'].dt.to_period('Q')

# ========== 3. SUM TOTAL VOLUME PER (QUARTER, HS CODE) ==========
# We'll call the columns "Quantity" or "Volume" depending on your dataset.
# Modify if you use "Weight" or something else.

group_total = (df
   .groupby(['Quarter', 'HS Code'], as_index=False)
   .agg(TotalVolume=('Quantity', 'sum'),FullDescription=('HS Code Full Description', 'first'))
)

#print(group_total.head(500000))

# ========== 4. SUPPLIER-LEVEL VOLUME PER (QUARTER, HS CODE, SUPPLIER) ==========
group_supplier = (df
   .groupby(['Quarter', 'HS Code', 'Supplier Name'], as_index=False)
   .agg(SupplierVolume=('Quantity', 'sum'))
)

# %%
# 1. Make sure your estimated dates are datetimes
df['Estimated Arrival Date'] = pd.to_datetime(
    df['Estimated Arrival Date'],
    errors='coerce'
)

# 2. Compute delay in days (positive = late; negative = early)
df['DelayDays'] = (df['Arrival Date'] - df['Estimated Arrival Date']).dt.days

# 3. (Optional) If you only care about magnitude of deviation, use absolute delay:
# df['AbsDelayDays'] = df['DelayDays'].abs()

# 4. Group by quarter and compute average delay
avg_delay_q = (
    df
    .groupby('Quarter', as_index=False)
    .agg(AverageDelayDays=('DelayDays', 'mean'))
)

print(avg_delay_q)
# Out:
#    Quarter  AverageDelayDays
# 0   2015Q1          9.315617
# 1   2015Q2          2.883594
# 2   2015Q3          1.845950
# 3   2015Q4          0.902560
# 4   2016Q1          2.970874
# 5   2016Q2          2.349345
# 6   2016Q3          0.866489
# 7   2016Q4          1.537223
# 8   2017Q1          1.784477
# 9   2017Q2          0.860528
# 10  2017Q3          1.240000
# 11  2017Q4          1.299592
# 12  2018Q1          1.898042
# 13  2018Q2          1.917864
# 14  2018Q3          1.618563
# 15  2018Q4          2.035510
# 16  2019Q1          1.703704
# 17  2019Q2          2.089046
# 18  2019Q3          1.056118
# 19  2019Q4          1.031042
# 20  2020Q1          1.563294
# 21  2020Q2          1.369375
# 22  2020Q3          1.440794
# 23  2020Q4          2.946099
# 24  2021Q1          5.018732
# 25  2021Q2          3.421642
# 26  2021Q3          3.721374
# 27  2021Q4          3.641379
# 28  2022Q1          5.469341
# 29  2022Q2          3.545242
# 30  2022Q3          3.257282
# 31  2022Q4          2.639785
# 32  2023Q1          2.084053
# 33  2023Q2          1.023684
# 34  2023Q3          1.981395
# 35  2023Q4          1.517847
# 36  2024Q1          2.313628
# 37  2024Q2          1.548510
# 38  2024Q3          1.643914

# %%
# ——— 2) Export to Excel ———
avg_delay_q.to_excel("quarterly_data_delayford.xlsx", index=False)
print("Excel file saved as 'quarterly_data.xlsx'.")
# Out:
# Excel file saved as 'quarterly_data.xlsx'.

# %%
check = df.groupby('Quarter')['DelayDays'] \
          .agg(TotalDelay=('sum'), Observations=('count'))
check['MeanViaCalc'] = check['TotalDelay'] / check['Observations']
print(check)
# Out:
#          TotalDelay  Observations  MeanViaCalc
# Quarter
# 2015Q1      11393.0          1223     9.315617
# 2015Q2       4236.0          1469     2.883594
# 2015Q3       2780.0          1506     1.845950
# 2015Q4       2186.0          2422     0.902560
# 2016Q1       4590.0          1545     2.970874
# 2016Q2       3766.0          1603     2.349345
# 2016Q3       1298.0          1498     0.866489
# 2016Q4       2292.0          1491     1.537223
# 2017Q1       2575.0          1443     1.784477
# 2017Q2       1271.0          1477     0.860528
# 2017Q3       1705.0          1375     1.240000
# 2017Q4       1913.0          1472     1.299592
# 2018Q1       2811.0          1481     1.898042
# 2018Q2       2802.0          1461     1.917864
# 2018Q3       2546.0          1573     1.618563
# 2018Q4       3210.0          1577     2.035510
# 2019Q1       2300.0          1350     1.703704
# 2019Q2       2956.0          1415     2.089046
# 2019Q3       1355.0          1283     1.056118
# 2019Q4       1860.0          1804     1.031042
# 2020Q1       3569.0          2283     1.563294
# 2020Q2       2039.0          1489     1.369375
# 2020Q3       1886.0          1309     1.440794
# 2020Q4       4154.0          1410     2.946099
# 2021Q1       6966.0          1388     5.018732
# 2021Q2       4585.0          1340     3.421642
# 2021Q3       4875.0          1310     3.721374
# 2021Q4       4224.0          1160     3.641379
# 2022Q1       7225.0          1321     5.469341
# 2022Q2       4545.0          1282     3.545242
# 2022Q3       4697.0          1442     3.257282
# 2022Q4       3437.0          1302     2.639785
# 2023Q1       2653.0          1273     2.084053
# 2023Q2       1556.0          1520     1.023684
# 2023Q3       2982.0          1505     1.981395
# 2023Q4       2594.0          1709     1.517847
# 2024Q1       3718.0          1607     2.313628
# 2024Q2       2442.0          1577     1.548510
# 2024Q3       1999.0          1216     1.643914

# %%
# ——— 1) Plot the average delay per quarter ———
plt.figure()
plt.plot(avg_delay_q['Quarter'].astype(str), avg_delay_q['AverageDelayDays'])
plt.xlabel('Quarter')
plt.ylabel('Average Delay (days)')
plt.title('Average Shipment Delay per Quarter')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
